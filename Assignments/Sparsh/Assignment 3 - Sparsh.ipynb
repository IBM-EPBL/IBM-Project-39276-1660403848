# %% [markdown]
# ## Assignment 3 - Abalone Age Prediction

# %% [markdown]
# ### Sparsh Kumar Sharoff - 2019115101

# %% [markdown]
# #### 1. Download the dataset:

# %% [markdown]
# #### 2. Load the dataset into the tool.

# %%
import pandas as pd
df = pd.read_csv("./Abalone.csv")

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.corr()
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole weight          0.966375      0.955355  0.540390
# ...

# %% [markdown]
# #### 3. Perform Visualizations

# %% [markdown]
# #### Univariate Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x=df['Sex'])
plt.show()

# %%
plt.hist(df['Diameter'])
plt.show()

# %% [markdown]
# #### Bi-Variate Analysis

# %%
plt.scatter(df['Length'],df['Diameter'])
plt.show()

# %%
plt.scatter(df['Height'],df['Rings'])
plt.show()

# %%
plt.scatter(df['Shucked weight'],df['Whole weight'])
plt.show()

# %% [markdown]
# #### Multi-Variate Analysis

# %%
sns.pairplot(df, kind = "scatter")
plt.show()

# %% [markdown]
# #### 4. Perform descriptive statistics on the dataset

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %% [markdown]
# #### 5. Check for Missing Values and deal with them

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# #### 6. Find the outliers and replace the outliers

# %%
list_ = ['Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings' ]

# %%
df.quantile(q=(0.25,0.75))
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0.25   0.450      0.35   0.115        0.4415           0.186          0.0935
# 0.75   0.615      0.48   0.165        1.1530           0.502          0.2530
#
#       Shell weight  Rings
# 0.25         0.130    8.0
# 0.75         0.329   11.0

# %%
df.plot(kind="box",subplots=True, layout = (2,4), figsize=(20,15))
plt.show()

# %%
import numpy as np
for x in list_:
    print("{:<15} - ".format(x),np.mean(df[x]))
# Out:
# Length          -  0.5239920995930099
# Diameter        -  0.407881254488869
# Height          -  0.1395163993296614
# Whole weight    -  0.82874215944458
# Shucked weight  -  0.35936748862820106
# Viscera weight  -  0.18059360785252604
# Shell weight    -  0.23883085946851795
# Rings           -  9.933684462532918

# %%
for x in list_:
    Q1 = df[x].quantile(0.25)
    Q3 = df[x].quantile(0.75)
    IQR = Q3 - Q1
    upper = Q3 + 1.5 * IQR
    lower = Q1 - 1.5 * IQR
    df[x] = np.where(df[x] > upper, upper, df[x])
    df[x] = np.where(df[x] < lower, lower, df[x])

# %%
df.plot(kind="box",subplots=True, layout = (2,4), figsize=(20,15))
plt.show()

# %% [markdown]
# #### 7. Check for Categorical columns and perform encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["Sex"] = le.fit_transform(df["Sex"])

# %%
df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500   15.0
# 1             0.0485        0.0700    7.0
# 2             0.1415        0.2100    9.0
# ...

# %% [markdown]
# #### 8. Split the data into dependent and independed variables

# %%
y = df['Rings']
y.head(5)
# Out:
# 0    15.0
# 1     7.0
# 2     9.0
# 3    10.0
# 4     7.0
# Name: Rings, dtype: float64

# %%
x = df.drop(columns=['Rings'], axis=1)
x.head(5)
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight
# 0          0.1010         0.150
# 1          0.0485         0.070
# 2          0.1415         0.210
# 3          0.1140         0.155
# 4          0.0395         0.055

# %% [markdown]
# #### 9. Scale the independent variables

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X
#       Viscera weight  Shell weight
# 17         -0.859260     -0.791736
# 1131        0.020405     -0.234841
# 299        -1.121778     -1.194752
# ...

# %%
y_train.head(10)
# Out:
# 4014    10.0
# 3252    12.0
# 305      4.0
# 1857     8.0
# 439     13.0
# 713      8.0
# 3553     9.0
# 1123     8.0
# 3244    15.5
# 2414     9.0
# Name: Rings, dtype: float64

# %%
y_test.head(10)
# Out:
# 17      10.0
# 1131     8.0
# 299      9.0
# 1338    10.0
# 2383    15.5
# 2039     6.0
# 3127     9.0
# 791     10.0
# 3599    12.0
# 1566     9.0
# Name: Rings, dtype: float64

# %%
print("Shapes: ")
print("x-train : ",x_train.shape)
print("x-test  : ",x_test.shape)
print("y-train : ",y_train.shape)
print("y-test  : ",y_test.shape)
# Out:
# Shapes:
# x-train :  (3132, 8)
# x-test  :  (1045, 8)
# y-train :  (3132,)
# y-test  :  (1045,)

# %% [markdown]
# #### 11. Build the model

# %%
from sklearn.linear_model import LinearRegression
from sklearn import svm
LR = LinearRegression()
SVM = svm.SVR()

# %% [markdown]
# #### 12. Train the model

# %%
LR.fit(x_train, y_train)
SVM.fit(x_train, y_train)
# Out:
# SVR()

# %% [markdown]
# #### 13. Test the models

# %% [markdown]
# Linear Regression

# %%
y_pred_LR = LR.predict(x_test)
y_pred_LR
# Out:
# array([ 8.29162097,  7.46574935,  7.94142784, ..., 12.34161251,
#         5.99212007, 10.30286241])

# %% [markdown]
# SVM

# %%
y_pred_SVM = SVM.predict(x_test)
y_pred_SVM
# Out:
# array([ 9.14179753,  7.74274715,  8.30466613, ..., 11.76608586,
#         4.86355009, 11.05707674])

# %% [markdown]
# #### 14. Measure the performance using metrics

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# R2 Score

# %%
r2_LR = r2_score(y_test,y_pred_LR)
print("R2 score of Linear Regression: ",r2_LR)
r2_SVM = r2_score(y_test, y_pred_SVM)
print("R2 score of SVM:               ",r2_SVM)
# Out:
# R2 score of Linear Regression:  0.5602301105767289
# R2 score of SVM:                0.5888531857284

# %% [markdown]
# Mean Absolute Error

# %%
mae_LR = mean_absolute_error(y_test,y_pred_LR)
print("Mean Absolute Error of Linear Regression: ",mae_LR)
mae_SVM = mean_absolute_error(y_test, y_pred_SVM)
print("Mean Absolute Error of SVM:",mae_SVM)
# Out:
# Mean Absolute Error of Linear Regression:  1.4102933483483402
# Mean Absolute Error of SVM: 1.3170726019376608

# %% [markdown]
# Mean Squared Error

# %%
mse_LR = mean_squared_error(y_test,y_pred_LR)
print("Mean Squared Error of Linear Regression: ",mse_LR)
mse_SVM = mean_squared_error(y_test, y_pred_SVM)
print("Mean Squared Error of SVM:",mse_SVM)
# Out:
# Mean Squared Error of Linear Regression:  3.3063056267215227
# Mean Squared Error of SVM: 3.091109823861639
