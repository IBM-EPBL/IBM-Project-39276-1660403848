# %% [markdown]
# # Assignment 2 - Data Visualization and Pre-processing

# %% [markdown]
# ### Sparsh Kumar Sharoff - 2019115101

# %% [markdown]
# ## 1.  Download the dataset

# %% [markdown]
# ## 2. Load the dataset

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("./Dataset/Churn_Modelling.csv")

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.corr()
# Out:
#                  RowNumber  CustomerId  CreditScore       Age    Tenure  \
# RowNumber         1.000000    0.004202     0.005840  0.000783 -0.006495
# CustomerId        0.004202    1.000000     0.005308  0.009497 -0.014883
# CreditScore       0.005840    0.005308     1.000000 -0.003965  0.000842
# Age               0.000783    0.009497    -0.003965  1.000000 -0.009997
# Tenure           -0.006495   -0.014883     0.000842 -0.009997  1.000000
# Balance          -0.009067   -0.012419     0.006268  0.028308 -0.012254
# NumOfProducts     0.007246    0.016972     0.012238 -0.030680  0.013444
# HasCrCard         0.000599   -0.014025    -0.005458 -0.011721  0.022583
# IsActiveMember    0.012044    0.001665     0.025651  0.085472 -0.028362
# EstimatedSalary  -0.005988    0.015271    -0.001384 -0.007201  0.007784
# Exited           -0.016571   -0.006248    -0.027094  0.285323 -0.014001
#
#                   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ## 3. Perform Below Visualizations.

# %% [markdown]
# ### Univariate Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(rc={'figure.figsize':(20,5)})
sns.countplot(df['Age'])

# %%
plt.hist(df['CreditScore'])
plt.xlabel("CreditScore")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Bi - Variate Analysis

# %%
sns.regplot(x='CreditScore', y='Balance', data=df, color='red', scatter_kws={'s':2})

# %%
sns.lineplot(x=df['Tenure'], y=df['CreditScore'])

# %% [markdown]
# ### Multi - Variate Analysis

# %%
sns.pairplot(df, kind="scatter")

# %% [markdown]
# ## 4. Perform descriptive statistics on the dataset.

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# ## 5. Handle the Missing values

# %%
sns.heatmap(df.isnull())

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ## 6. Find the outliers and replace the outliers

# %%
df.quantile(q=(0.25,0.75))
# Out:
#       RowNumber   CustomerId  CreditScore   Age  Tenure    Balance  \
# 0.25    2500.75  15628528.25        584.0  32.0     3.0       0.00
# 0.75    7500.25  15753233.75        718.0  44.0     7.0  127644.24
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0.25            1.0        0.0             0.0       51002.1100     0.0
# 0.75            2.0        1.0             1.0      149388.2475     0.0

# %%
sns.boxplot(df['CreditScore'])

# %%
np.median(df['CreditScore'])
# Out:
# 652.0

# %%
q1=df['CreditScore'].quantile(0.25)
q3=df['CreditScore'].quantile(0.75)
iqr=q3-q1
upper=q3+1.5*iqr
lower=q1-1.5*iqr
df['CreditScore']=np.where(df['CreditScore'] > upper, upper, df['CreditScore'])
df['CreditScore']=np.where(df['CreditScore'] < lower, lower, df['CreditScore'])

# %%
sns.boxplot(df['CreditScore'])

# %% [markdown]
# ## 7. Check for Categorical columns and perform encoding.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df["Gender"] = le.fit_transform(df["Gender"])
df["Geography"] = le.fit_transform(df["Geography"])

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore  Geography  Gender  Age  \
# 0             1    15634602   Hargrave        619.0          0       0   42
# 1             2    15647311       Hill        608.0          2       0   41
# 2             3    15619304       Onio        502.0          0       0   42
# 3             4    15701354       Boni        699.0          0       0   39
# 4             5    15737888   Mitchell        850.0          2       0   43
# ...         ...         ...        ...          ...        ...     ...  ...
# 9995       9996    15606229   Obijiaku        771.0          0       1   39
# 9996       9997    15569892  Johnstone        516.0          0       1   35
# 9997       9998    15584532        Liu        709.0          0       0   36
# 9998       9999    15682355  Sabbatini        772.0          1       1   42
# 9999      10000    15628319     Walker        792.0          0       0   28
#
# ...

# %% [markdown]
# ## 8. Split the data into dependent and independent variables

# %%
x = df.drop(columns=['Exited', 'CustomerId', 'Surname', 'RowNumber'], axis=1)
y = df['Exited']

# %%
x.head()
# Out:
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0        619.0          0       0   42       2       0.00              1
# 1        608.0          2       0   41       1   83807.86              1
# 2        502.0          0       0   42       8  159660.80              3
# 3        699.0          0       0   39       1       0.00              2
# 4        850.0          2       0   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Exited, dtype: int64

# %% [markdown]
# ## 9. Scale the independent variables

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X = scaler.fit_transform(x)
x = pd.DataFrame(X, columns = x.columns)

# %%
x
# Out:
#       CreditScore  Geography    Gender       Age    Tenure   Balance  \
# 0       -0.326878  -0.901886 -1.095988  0.293517 -1.041760 -1.225848
# 1       -0.440804   1.515067 -1.095988  0.198164 -1.387538  0.117350
# 2       -1.538636  -0.901886 -1.095988  0.293517  1.032908  1.333053
# 3        0.501675  -0.901886 -1.095988  0.007457 -1.387538 -1.225848
# 4        2.065569   1.515067 -1.095988  0.388871 -1.041760  0.785728
# ...           ...        ...       ...       ...       ...       ...
# 9995     1.247373  -0.901886  0.912419  0.007457 -0.004426 -1.225848
# 9996    -1.393640  -0.901886  0.912419 -0.373958  1.724464 -0.306379
# 9997     0.605244  -0.901886 -1.095988 -0.278604  0.687130 -1.225848
# 9998     1.257730   0.306591  0.912419  0.293517 -0.695982 -0.022608
# 9999     1.464868  -0.901886 -1.095988 -1.041433 -0.350204  0.859965
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0         -0.911583   0.646092        0.970243         0.021886
# ...

# %% [markdown]
# ## 10. Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=10)

# %%
x_train.head()
# Out:
#       CreditScore  Geography    Gender       Age    Tenure   Balance  \
# 5663     2.065569  -0.901886 -1.095988 -0.087897 -1.041760 -1.225848
# 2840    -1.269357   1.515067  0.912419  0.102810 -0.350204 -1.225848
# 4550    -0.741154  -0.901886 -1.095988  0.007457 -0.695982  1.442685
# 17      -1.051861   1.515067 -1.095988 -1.422847  1.378686 -1.225848
# 3442     2.065569   0.306591 -1.095988 -0.850726  1.032908  1.256275
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 5663       0.807737   0.646092       -1.030670        -1.583706
# 2840       0.807737   0.646092       -1.030670        -1.298794
# 4550       0.807737   0.646092       -1.030670        -0.108761
# 17         0.807737   0.646092        0.970243        -1.489956
# 3442      -0.911583   0.646092        0.970243        -0.798135

# %%
x_test.head()
# Out:
#       CreditScore  Geography    Gender       Age    Tenure   Balance  \
# 937      2.065569   0.306591 -1.095988  0.484225 -0.004426  0.835324
# 9355     0.915952   1.515067 -1.095988  0.102810  1.032908 -1.225848
# 2293     0.398106   1.515067 -1.095988  0.579578 -1.733315 -0.299734
# 192     -1.776845  -0.901886  0.912419  0.102810 -1.387538 -1.225848
# 8675     0.657029  -0.901886  0.912419  1.437761  0.687130  0.795384
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 937       -0.911583  -1.547768        0.970243         1.234723
# 9355      -0.911583   0.646092       -1.030670         1.164024
# 2293      -0.911583   0.646092       -1.030670         1.699145
# 192        0.807737  -1.547768       -1.030670         0.259204
# 8675      -0.911583   0.646092       -1.030670         0.220617

# %%
y_train.head()
# Out:
# 5663    0
# 2840    0
# 4550    0
# 17      0
# 3442    0
# Name: Exited, dtype: int64

# %%
y_test.head()
# Out:
# 9394    0
# 898     1
# 2398    0
# 5906    0
# 2343    0
# Name: Exited, dtype: int64
